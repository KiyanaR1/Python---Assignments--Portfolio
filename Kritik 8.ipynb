# %%
def gradient_descent(x0, y0,f, grad_f, alpha, num_iterations):
    """Parameters:
    x0, y0: Initial point for the descent.
    f: a function of two variables
    grad_f: the gradient of f
    alpha: Learning rate.
    num_iterations: Number of iterations to perform.
    Returns:
    (x, y): The coordinates of the final point after gradient descent.
    """
    x, y = x0, y0 # Initialize x and y with the initial point
    for i in range(num_iterations):
        # obtain the gradient of f at (x, y)
        grad_x, grad_y = grad_f(x,y)
        # Update x and y by taking a step in the
        # opposite direction of the gradient
        x = x - alpha * grad_x ## Update the variables: Adjust the variables in the opposite direction of the gradient
        y =  y - alpha * grad_y
    return x, y

# %%
def fun_1(x,y): ## defineing function 1
    return x**2+y**2
def grad_f_1(x,y):
    grad_x = 2*x 
    grad_y = 2*y
    return grad_x, grad_y

# %%
gradient_descent(0.1, 0.1,fun_1, grad_f_1, 0.1, 10) ##apply your gradient descent to the following test cases
# Out:
# (0.010737418240000003, 0.010737418240000003)

# %%
gradient_descent(-1, 1,fun_1, grad_f_1, 0.01, 100) ##apply your gradient descent to the following test cases
# Out:
# (-0.13261955589475316, 0.13261955589475316)

# %%
import numpy as np

def fun_2(x,y):
    return 1-np.exp(-x**2-(y-2)**2)-2*np.exp(-x**2-(y+2)**2)
def grad_f_2(x,y):
    grad_x = 2*x*np.exp(-x**2-(y-2)**2) + 4*np.exp(-x**2-(y+2)**2)
    grad_y = 2*(y-2)*np.exp(-x**2-(y-2)**2) + 4*(y+2) *np.exp(-x**2-(y+2)**2)
    return grad_x, grad_y

# %%
gradient_descent(0, 1,fun_2, grad_f_2, 0.01, 10000) ##apply your gradient descent to the following test cases
# Out:
# (-2.2507197046886613e-07, 1.9999990997123154)

# %%
gradient_descent(0, -1,fun_2, grad_f_2, 0.01, 10000) ##apply your gradient descent to the following test cases
# Out:
# (-2.7580235212413093, -1.937342980012361)

# %%
def fun_2(x, y):
    return 1 - np.exp(-x**2 - (y-2)**2) - 2*np.exp(-x**2 - (y+2)**2)

import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %matplotlib widget

## creating scale
X = np.linspace(-5, 5, 100)
Y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(X, Y)
z = fun_2(x, y)

fig = plt.figure()
ax = fig.add_subplot( projection='3d')  # Use add_subplot for 3D projection
ax.plot_surface(x, y, z, cmap='viridis') # make colourful

###creating labels
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
ax.set_title('function plot')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
